# %%
import os
import pandas as pd
import seaborn as sns

from matplotlib import pyplot as plt

# %%
file_path = '../data/fix_noise.parquet'
output_file_path = '../data/done.parquet'

if not os.path.exists(file_path):
    print(f"File not found: {file_path}")

df = pd.read_parquet(file_path)
# df.dtypes

# %% [markdown]
# ## What we will drop
# - I would drop `length and bread` or `ship type` as they create with each other or maybe all
# - Maybe `Start Longitude` and `Start Latitude` as they are encoded in ports and do we really need specific dock?
# - Maybe `End Longitude` and `End Latitude` as they are encoded in ports and do we really need specific dock?
