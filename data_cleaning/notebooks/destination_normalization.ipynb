# %%
import os
import pandas as pd

from data_cleaning.dest_normalization import *

# %%
file_path = '../../data/type_consistent_data.parquet'

if not os.path.exists(file_path):
    print(f"File not found: {file_path}")

df = pd.read_parquet(file_path)
df.head()

df.dtypes
# Out:
# TripID                          int64
# StartLatitude                 float64
# StartLongitude                float64
# StartTime         datetime64[ns, UTC]
# EndLatitude                   float64
# EndLongitude                  float64
# EndTime           datetime64[ns, UTC]
# StartPort                    category
# EndPort                      category
# time              datetime64[ns, UTC]
# shiptype                        int64
# Length                          int64
# Breadth                         int64
# Draught                       float64
# Latitude                      float64
# Longitude                     float64
# SOG                           float64
# COG                           float64
# TH                              int64
# Destination            string[python]
# AisSourcen             string[python]
# dtype: object

# %% [markdown]
# ## ==================================== Remark
# Destinations are being processed so only official ports are left and nothing else (can be changed by looking for NOTE comment)
# ## ====================================

# %% [markdown]
# ## ==================================== Step 1
# Deal with Inconsistent Records (We can have different formats representing the same thing) if they are there.
# And convert columns to categorical where appropriate.
# ## ====================================

# %%
def check_unique_values(df):
    """Check unique values in each column of the DataFrame."""
    col_un = {}
    for col in df.columns:
        clean_series = df[col].dropna()
        nunique = clean_series.nunique()
        col_un[col] = nunique
    return col_un

unique_values_before = check_unique_values(df)
unique_values_before
# Out:
# {'TripID': 1126,
#  'StartLatitude': 28,
#  'StartLongitude': 34,
#  'StartTime': 953,
#  'EndLatitude': 29,
#  'EndLongitude': 47,
#  'EndTime': 943,
#  'StartPort': 2,
#  'EndPort': 2,
#  'time': 414193,
#  'shiptype': 11,
#  'Length': 107,
#  'Breadth': 36,
#  'Draught': 238,
#  'Latitude': 273,
#  'Longitude': 1285,
#  'SOG': 227,
#  'COG': 3602,
#  'TH': 361,
#  'Destination': 140,
#  'AisSourcen': 224}

# %% [markdown]
# Column: StartPort, Unique values: 2 - seems correct
# Column: EndPort, Unique values: 2 - seems correct
#
# Column: Destination, Unique values: 140 - weird
# Column: AisSourcen, Unique values: 224 - should check if it is correct

# %%
# Case normalization
text_columns = df.select_dtypes(include=['string']).columns
for col in text_columns:
    df[col] = df[col].str.upper()  # Ensure string type and uppercase

unique_values_after = check_unique_values(df)

changed_columns = list(filter(lambda col: unique_values_after[col] != unique_values_before[col], df.columns))
df[changed_columns].dropna().nunique() # Check how many unique values are there after case normalization
# Out:
# Destination    139
# dtype: int64

# %% [markdown]
# Case normalization has changed the unique values in the following columns: Destination
# It seems there are still inconsistencies in the Destination column, so we will need to clean it further.

# %%
df['Destination'].unique() #See some examples of the Destination column
# Out:
# <StringArray>
# [            'HAMBURG',               'DEHAM',               'DEBRE',
#                'DEBRV',             'ELBE.RC',          'HAMBURG.:)',
#  'BREMERHAVEN.VIA.NOK',              'DE.HAM',    'DE.HAMBIVER.ELBE',
#              'ELBE.PS',
#  ...
#             'HALMSTAD',               'GDYNA',         'GDANSK...AS',
#         'BRUNSBUETTEL',         'KALININGRAD',            'SZCZECIN',
#                'SEHAD',       'GDANSK.VIANOK',           'GDYNIA.PL',
#               'GDANKS']
# Length: 139, dtype: string

# %%
df['Destination'] = df['Destination'].where(
        df['Destination'].str.contains(r'[A-Za-z]', na=False),
        "NAN"
    ) # Atle ast one alphabetic

df['Destination'] = df['Destination'].apply(
    lambda x: "NAN" if re.match(r'^[A-Z]{2}$', str(x)) else x
) #only country code

def find_values_with_special_chars(df):
    """Find values with special characters in the 'Destination' column."""
    return [
        value for value in df['Destination'].unique()
        if re.search(r'[^A-Za-z0-9]', str(value))
    ]

# %%
dest_before = find_values_with_special_chars(df)
print(len(dest_before), "unique values before cleaning with special characters")
dest_before
# Out:
# 99 unique values before cleaning with special characters
# ['ELBE.RC',
#  'HAMBURG.:)',
#  'BREMERHAVEN.VIA.NOK',
#  'DE.HAM',
#  'DE.HAMBIVER.ELBE',
#  'ELBE.PS',
#  'HHLO.PS',
#  'HAMBURG.DE',
#  'HAMBURG/.AIRBUS',
#  'BLEXEN.ROAD',
#  'BRV.PS',
#  'HH.FINKENWERDER',
#  'DEBRV.>.DEHAM',
#  'DEHAM.ELBE.PLT',
#  'DEHAM.ELBE',
#  'DEHAM.CTT',
#  'SEAHU.>.DEBRV',
#  'DEBRT.>.DEHAM',
#  'DE.BRV>DEHAM',
#  'DE.BRV>DE.HAM',
#  'HAMBURG..DE',
#  'DEBRV>DEHAM',
#  'DEHAM.EGH',
#  'DEHAM.CTA',
#  'DEHAM.EG',
#  'DE.HAM.............',
#  'DE.WVN.>.DE.HAM',
#  'DEBHV.NOK',
#  'DEBRV.EGH',
#  'DEBRV---->DEHAM',
#  'HAMBURG/EUR',
#  'DEBRV.>.DEIM',
#  'HH.PS',
#  'HH.CTB',
#  'HAM.PS',
#  'HAMBURG....',
#  'HAMBURG???',
#  'GDYNIA.VIA.NOK',
#  'GDYNIA.VIA.NOK.:)',
#  'GDYNIAVIA)NOK',
#  'KLJ.VIA.NOK',
#  'PLGDN.VIA.NOK',
#  'GDYNIA.VIA',
#  'GDYNIA.VIAE',
#  'GDYNIA.VIBIA.NOK',
#  'GDYNIA.VI',
#  "'GDYNIA.VIK?0\\\\BPO?_'",
#  'GDYNIA.VIE',
#  'GDANSK.VIA.NOK',
#  'GDYNIA...TH',
#  'GDANSK.VICEL',
#  'KLAIPEDA.VIA.NOK',
#  'KLAIPEDA..=SWIN',
#  'GDANSK....=SWIN',
#  'GDANSK.VIA.KIEL.K',
#  'PL.GDY',
#  'PL.GDY.VIA.NOK',
#  'GDYNIA...!RSBURG',
#  'KLAIPEDA.VIA.NOC',
#  'GDYNIA.VIA.K.CANAL',
#  'GDANSK.PILOT',
#  'GDANSKVIA.NOK)',
#  'GDYNIA....>.BALTIC.2',
#  'GDYNIA....ROJECT',
#  'GDYNIA...!E',
#  'GDYNIA...!STELLE',
#  'PL.GDN',
#  'GDYNIA...!RATION',
#  'GDYNIA....>.HANKO',
#  'GDYNIA...DING.AREA',
#  'DEHAM.>.PLGDY',
#  'DEHAM.>.PLGDY.NOK',
#  'DEHAM.>.PL',
#  'GDYNIA.VIA.KIEL',
#  'GDYNIA.:)',
#  'GDYNIA/N.O.K',
#  'GDANSK....NOK',
#  'GDYNIA>HIDDENSEE',
#  'BE.ANR.>>.PL.GDN',
#  'GDYNIA-PLGDY',
#  'GDYNIA.POLAND',
#  'KIEL.CANAL-TRANS',
#  'PLGDY.VIA.NOK',
#  'GDANSK....KCHIODE',
#  'GDANSK...!',
#  'GDANSK...#INDFARM',
#  'KIEL.CANAL',
#  'GDANSK...!A.KIEL',
#  'GDANSK...',
#  'GDANSKVIA.NOK',
#  'GDYNIA.VICINOUJSCIE',
#  'GDYNIA..VIA.NOK',
#  'GDANSKCIKINGER.WF',
#  'LT.KLAIPEDA',
#  'GDYNIA....Y',
#  'GDANSK./.POLAND',
#  'GDANSK...AS',
#  'GDANSK.VIANOK',
#  'GDYNIA.PL']

# %% [markdown]
# ## ==================================== Step 2
# We can see that we have different formats representing the same thing, like 'HAMBURG' and 'DEHAM' ext.
# The data is incredibly messy, we need to handle country codes, special characters, and different formats.
#
# 1. Some have country codes
# 2. Some contain starting port too
# 3. Some contain type of facilities (e.g., 'ELBE.RC', 'BREMERHAVEN.VIA.NOK')
#
# start > destination
# ## ====================================

# %%
# Clean all data
df['Destination'] = df['Destination'].apply(clean_destination)
df['Destination'].unique()
# Out:
# array(['HAMBURG', 'DEHAM', 'DEBRE', 'DEBRV', 'ELBE.RC',
#        'BREMERHAVEN.VIA.NOK', 'DE.HAM', 'DE.HAMBIVER.ELBE', 'ELBE.PS',
#        'HHLO.PS', 'HAMBURG.DE', 'HAMBURG/AIRBUS', 'BREMENHAVEN',
#        'FINKENWERDER', 'BLEXEN.ROAD', 'BRV.PS', 'HH.FINKENWERDER',
#        'DEBRV>DEHAM', 'COPENHAGEN', 'DEHAM.ELBE.PLT', 'DEHAM.ELBE',
#        'DEHAM.CTT', 'SEAHU>DEBRV', 'DEBRT>DEHAM', 'STADE', 'DE.BRV>DEHAM',
#        'DE.BRV>DE.HAM', 'DEHAMCTA', 'BREMERHAVEN', 'DEHAM.EGH',
#        'DEHAM.CTA', 'DEHAM.EG', 'HAMBUG', 'DEBHV', 'DE.WVN>DE.HAM',
#        'DEBHV.NOK', 'NAN', 'DEBRV.EGH', 'HAMBURG/EUR', 'DEBRV>DEIM',
#        'GDANSK', 'HH.PS', 'HH.CTB', 'HAM.PS', 'FINKENWERD', 'NORDENHAM',
#        'GDYNIA.VIA.NOK', 'GDYNIA', 'GYDINIA', 'GDYNIAVIANOK',
#        'KLJ.VIA.NOK', 'PLGDY', 'PLGDN.VIA.NOK', 'GDYNIA.VIA',
#        'GDYNIA.VIAE', 'GDYNIA.VIBIA.NOK', 'GDYNIA.VI', 'GDYNIA.VIK0/BPO',
#        'GDYNIA.VIE', 'GDANSK.VIA.NOK', 'GDYNIA.TH', 'GDANSK.VICEL',
#        'KLAIPEDA.VIA.NOK', 'KLAIPEDA', 'KLAIPEDA.SWIN', 'GDANSK.SWIN',
#        'GDANK', 'GDANSK.VIA.KIEL.K', 'PL.GDY', 'PL.GDY.VIA.NOK',
#        'GDYNIA.RSBURG', 'KLAIPEDA.VIA.NOC', 'GDYNIA.VIA.K.CANAL',
#        'GDANSK.PILOT', 'GDANSKVIA.NOK', 'GDYNIA>BALTIC.2',
#        'GDYNIA.ROJECT', 'GDYNYA', 'PLGDN', 'GDYNIA.E', 'GDYNIA.STELLE',
#        'PL.GDN', 'GDYNIA.RATION', 'GDYNIA>HANKO', 'GDYNIA.DING.AREA',
#        'DEHAM>PLGDY', 'NOK', 'GYDNIA', 'DEHAM>PLGDY.NOK', 'DEHAM>PL',
#        'GDYNIA.VIA.KIEL', 'GDANSKARATION', 'KLAIPEDACINDFARM',
#        'GDYNIA/N.O.K', 'GDYNI', 'GDANSK.NOK', 'GDYNIASTRALSUND',
#        'GDYNIA>HIDDENSEE', 'GDYNIAC', 'GDYNIACRT', 'BE.ANR>PL.GDN',
#        'GDYNIAPLGDY', 'GDYNIA.POLAND', 'KIEL.CANALTRANS', 'PLGDY.VIA.NOK',
#        'GDANSK.KCHIODE', 'GDANSK.INDFARM', 'KIEL.CANAL', 'GDANSK.A.KIEL',
#        'GDYNIA.VICINOUJSCIE', 'GDANSKCIKINGER.WF', 'LT.KLAIPEDA',
#        'GDYNIA.Y', 'GDANSK/POLAND', 'HALMSTAD', 'GDYNA', 'GDANSK.AS',
#        'BRUNSBUETTEL', 'KALININGRAD', 'SZCZECIN', 'SEHAD',
#        'GDANSK.VIANOK', 'GDYNIA.PL', 'GDANKS'], dtype=object)

# %%
# Create mask for rows containing '>'
mask = df['Destination'].str.contains('>', na=False)

# Initialize columns (if not already done)
# df['start_fr_dest'] = None
# df['cleaned_destination'] = df['Destination'].copy()

# Split and assign values safely
# df.loc[mask, 'start_fr_dest'] = df.loc[mask, 'Destination'].str.split('>').str[0] #NOTE for now we wont bother
df.loc[mask, 'Destination'] = df.loc[mask, 'Destination'].str.split('>').str[1]
df
# Out:
#           TripID  StartLatitude  StartLongitude                 StartTime  \
# 0          39131          53.57            8.53 2016-01-24 08:06:00+00:00
# 1          39131          53.57            8.53 2016-01-24 08:06:00+00:00
# 2          39131          53.57            8.53 2016-01-24 08:06:00+00:00
# 3          39131          53.57            8.53 2016-01-24 08:06:00+00:00
# 4          39131          53.57            8.53 2016-01-24 08:06:00+00:00
# ...          ...            ...             ...                       ...
# 1060703  2204049          54.36           10.14 2017-04-03 07:54:00+00:00
# 1060704  2204049          54.36           10.14 2017-04-03 07:54:00+00:00
# 1060705  2204049          54.36           10.14 2017-04-03 07:54:00+00:00
# 1060706  2204049          54.36           10.14 2017-04-03 07:54:00+00:00
# 1060707  2204049          54.36           10.14 2017-04-03 07:54:00+00:00
#
#          EndLatitude  EndLongitude                   EndTime    StartPort  \
# 0              53.53          9.90 2016-01-24 16:44:00+00:00  BREMERHAVEN
# 1              53.53          9.90 2016-01-24 16:44:00+00:00  BREMERHAVEN
# 2              53.53          9.90 2016-01-24 16:44:00+00:00  BREMERHAVEN
# 3              53.53          9.90 2016-01-24 16:44:00+00:00  BREMERHAVEN
# 4              53.53          9.90 2016-01-24 16:44:00+00:00  BREMERHAVEN
# ...              ...           ...                       ...          ...
# 1060703        54.38         18.66 2017-04-04 15:28:00+00:00         KIEL
# 1060704        54.38         18.66 2017-04-04 15:28:00+00:00         KIEL
# 1060705        54.38         18.66 2017-04-04 15:28:00+00:00         KIEL
# 1060706        54.38         18.66 2017-04-04 15:28:00+00:00         KIEL
# 1060707        54.38         18.66 2017-04-04 15:28:00+00:00         KIEL
#
#          EndPort                      time  ...  Length  Breadth  Draught  \
# 0        HAMBURG 2016-01-24 08:07:00+00:00  ...     277       42    11.54
# 1        HAMBURG 2016-01-24 08:10:00+00:00  ...     277       42    11.54
# 2        HAMBURG 2016-01-24 08:10:00+00:00  ...     277       42    11.54
# 3        HAMBURG 2016-01-24 08:12:00+00:00  ...     277       42    11.54
# 4        HAMBURG 2016-01-24 08:16:00+00:00  ...     277       42    11.54
# ...          ...                       ...  ...     ...      ...      ...
# 1060703   GDYNIA 2017-04-04 13:57:00+00:00  ...      89       13     4.00
# 1060704   GDYNIA 2017-04-04 13:56:00+00:00  ...      89       13     4.00
# 1060705   GDYNIA 2017-04-04 13:55:00+00:00  ...      89       13     4.00
# 1060706   GDYNIA 2017-04-04 13:54:00+00:00  ...      89       13     4.00
# 1060707   GDYNIA 2017-04-04 13:53:00+00:00  ...      89       13     4.00
#
#          Latitude  Longitude  SOG    COG   TH  Destination  \
# 0           53.57       8.53  0.7  331.2  143      HAMBURG
# 1           53.57       8.53  1.6  315.3  117      HAMBURG
# 2           53.57       8.53  2.8  322.6  100      HAMBURG
# 3           53.57       8.53  2.8  286.3   74      HAMBURG
# 4           53.57       8.53  4.3  333.1  333      HAMBURG
# ...           ...        ...  ...    ...  ...          ...
# 1060703     54.51      18.75  7.2  221.0  215       GDANSK
# 1060704     54.51      18.75  7.2  221.9  215       GDANSK
# 1060705     54.51      18.75  7.2  222.1  215       GDANSK
# 1060706     54.51      18.76  7.2  221.2  215       GDANSK
# 1060707     54.51      18.76  7.2  221.0  214       GDANSK
#
#                    AisSourcen
# 0        DAIS1.81B.90B.71.71A
# 1        DAIS1.81B.90B.71.71A
# 2        DAIS1.81B.90B.71.71A
# 3        DAIS1.81B.90B.71.71A
# 4        DAIS1.81B.90B.71.71A
# ...                       ...
# 1060703                 H7001
# 1060704                 H7001
# 1060705                 H7001
# 1060706                 H7001
# 1060707                 H7001
#
# [1060708 rows x 21 columns]

# %% [markdown]
# #### **I CREATED CUSTOM FILE WITH FUNCTION WE WILL USE DOWN**
#
# df_recombined['Destination'].unique()
# Now we have somewhat cleaned Destination column, but we still have some inconsistencies. That the same ports have different names.
# I didn't find quicker way to do it, rather than manually checking the names and creating a list of names that represent the same port.
# We will only a bit automize this process, by using fuzzy matching to find similar names.
# And extracting all ports from UpdatedPub150.csv file, which contains ports and their countries.
# [link](https://msi.nga.mil/Publications/WPI)

# %%
# ports_cvs = '../data/UpdatedPub150.csv'
# port_df = pd.read_csv(ports_cvs)
# save_filtered_ports(port_df, country_name='Poland')
# save_filtered_ports(port_df, country_name='Germany')
# save_filtered_ports(port_df, country_name='Lithuania')
# save_filtered_ports(port_df, country_name='Sweden')

# %%
unique_dests = df['Destination'].unique().tolist()

# Find matches with threshold of 85
matches = find_fuzzy_matches(unique_dests, threshold=75, show_progress=True)

# Print results grouped by similarity
print_fuzzy_matches(matches, min_score=75, group_similar=True)
# Out:
# Processing 116/116: GDANKS......K...F.....
# ==================================================
#
# Fuzzy matches (score ≥ 75):
# ============================================================
#
# Group: BREMENHAVEN
# --------------------------------------------------
#   → BREMERHAVEN (score: 91)
#     → BREMERHAVEN.VIA.NOK (score: 100)
#
# Group: DE.HAM
# --------------------------------------------------
#   → DEHAM (score: 91)
#     → DEHAM.ELBE.PLT (score: 100)
#     → DEHAM.ELBE (score: 100)
#     → DEHAM.CTT (score: 100)
#     → DEHAM.EGH (score: 100)
#     → DEHAM.CTA (score: 100)
#     → DEHAM.EG (score: 100)
#     → DEHAMCTA (score: 77)
#   → HAMBURG.DE (score: 75)
#     → HAMBURG (score: 100)
#     → HAMBURG/EUR (score: 86)
#     → HAMBURG/AIRBUS (score: 82)
#     → HAMBUG (score: 75)
#
# Group: DE.HAMBIVER.ELBE
# --------------------------------------------------
#   → DEHAM.ELBE (score: 77)
#     → DEHAM (score: 100)
#     → DEHAM.ELBE.PLT (score: 100)
#     → DEHAM.EG (score: 78)
#
# Group: DEBHV
# --------------------------------------------------
#   → DEBHV.NOK (score: 100)
#     → NOK (score: 100)
#   → DEBRV (score: 80)
#     → DEBRV.EGH (score: 100)
#     → DEBRE (score: 80)
#
# Group: FINKENWERD
# --------------------------------------------------
#   → FINKENWERDER (score: 91)
#     → HH.FINKENWERDER (score: 100)
#   → HH.FINKENWERDER (score: 80)
#
# Group: GDANK
# --------------------------------------------------
#   → GDANSK (score: 91)
#     → GDANSK.VIA.NOK (score: 100)
#     → GDANSK.VICEL (score: 100)
#     → GDANSK.SWIN (score: 100)
#     → GDANSK.VIA.KIEL.K (score: 100)
#     → GDANSK.PILOT (score: 100)
#     → GDANSK.NOK (score: 100)
#     → GDANSK.KCHIODE (score: 100)
#     → GDANSK.INDFARM (score: 100)
#     → GDANSK.A.KIEL (score: 100)
#     → GDANSK/POLAND (score: 100)
#     → GDANSK.AS (score: 100)
#     → GDANSK.VIANOK (score: 100)
#     → GDANKS (score: 83)
#   → GDANKS (score: 91)
#
# Group: GDANSKARATION
# --------------------------------------------------
#   → GDYNIA.RATION (score: 77)
#     → GDYNIA (score: 100)
#     → GDYNIA.E (score: 86)
#     → GDYNIA.Y (score: 86)
#     → GDYNIA.VI (score: 80)
#     → GDYNIA.TH (score: 80)
#     → GDYNIA.PL (score: 80)
#     → GDYNIA.DING.AREA (score: 76)
#     → GDYNIA.VIA (score: 75)
#     → GDYNIA.VIE (score: 75)
#
# Group: GDANSKVIA.NOK
# --------------------------------------------------
#   → NOK (score: 100)
#     → BREMERHAVEN.VIA.NOK (score: 100)
#     → DEBHV.NOK (score: 100)
#     → GDYNIA.VIA.NOK (score: 100)
#     → KLJ.VIA.NOK (score: 100)
#     → PLGDN.VIA.NOK (score: 100)
#     → GDYNIA.VIBIA.NOK (score: 100)
#     → GDANSK.VIA.NOK (score: 100)
#     → KLAIPEDA.VIA.NOK (score: 100)
#     → PL.GDY.VIA.NOK (score: 100)
#     → PLGDY.NOK (score: 100)
#     → GDANSK.NOK (score: 100)
#     → PLGDY.VIA.NOK (score: 100)
#   → GDANSK.VIA.NOK (score: 96)
#     → GDANSK (score: 100)
#     → GDANSK.VIA.KIEL.K (score: 83)
#     → GDANSK.AS (score: 80)
#   → GDANSK.VIANOK (score: 92)
#     → GDANSK.SWIN (score: 75)
#   → GDANSK.NOK (score: 87)
#     → GDANSK.VICEL (score: 75)
#     → GDANSK.PILOT (score: 75)
#     → GDANSK.KCHIODE (score: 75)
#     → GDANSK.INDFARM (score: 75)
#     → GDANSK.A.KIEL (score: 75)
#     → GDANSK/POLAND (score: 75)
#   → PLGDN.VIA.NOK (score: 77)
#     → PLGDN (score: 100)
#
# Group: GDYNA
# --------------------------------------------------
#   → GDYNIA (score: 91)
#     → GDYNIA.VIA.NOK (score: 100)
#     → GDYNIA.VIA (score: 100)
#     → GDYNIA.VIAE (score: 100)
#     → GDYNIA.VIBIA.NOK (score: 100)
#     → GDYNIA.VI (score: 100)
#     → GDYNIA.VIK0/BPO (score: 100)
#     → GDYNIA.VIE (score: 100)
#     → GDYNIA.TH (score: 100)
#     → GDYNIA.RSBURG (score: 100)
#     → GDYNIA.VIA.K.CANAL (score: 100)
#     → GDYNIA.ROJECT (score: 100)
#     → GDYNIA.E (score: 100)
#     → GDYNIA.STELLE (score: 100)
#     → GDYNIA.RATION (score: 100)
#     → GDYNIA.DING.AREA (score: 100)
#     → GDYNIA.VIA.KIEL (score: 100)
#     → GDYNIA/N.O.K (score: 100)
#     → GDYNIA.POLAND (score: 100)
#     → GDYNIA.VICINOUJSCIE (score: 100)
#     → GDYNIA.Y (score: 100)
#     → GDYNIA.PL (score: 100)
#     → GDYNIAC (score: 92)
#     → GDYNI (score: 91)
#     → GDYNYA (score: 83)
#     → GYDNIA (score: 83)
#     → GDYNIACRT (score: 80)
#     → GYDINIA (score: 77)
#   → GDYNYA (score: 91)
#   → GDYNIAC (score: 83)
#   → GDYNI (score: 80)
#   → GDYNIA.E (score: 77)
#   → GDYNIA.Y (score: 77)
#
# Group: GDYNIAPLGDY
# --------------------------------------------------
#   → GDYNIA.PL (score: 80)
#     → GDYNIA (score: 100)
#     → PL (score: 100)
#     → GDYNIA.E (score: 86)
#     → GDYNIA.Y (score: 86)
#     → GDYNIA.POLAND (score: 82)
#     → GDYNIA.VIA.NOK (score: 80)
#     → GDYNIA.VIA (score: 80)
#     → GDYNIA.VIAE (score: 80)
#     → GDYNIA.VIBIA.NOK (score: 80)
#     → GDYNIA.VI (score: 80)
#     → GDYNIA.VIK0/BPO (score: 80)
#     → GDYNIA.VIE (score: 80)
#     → GDYNIA.TH (score: 80)
#     → PL.GDY (score: 80)
#     → GDYNIA.RSBURG (score: 80)
#     → GDYNIA.VIA.K.CANAL (score: 80)
#     → GDYNIA.ROJECT (score: 80)
#     → GDYNIA.STELLE (score: 80)
#     → PL.GDN (score: 80)
#     → GDYNIA.RATION (score: 80)
#     → GDYNIA.DING.AREA (score: 80)
#     → GDYNIA.VIA.KIEL (score: 80)
#     → GDYNIA/N.O.K (score: 80)
#     → GDYNIA.VICINOUJSCIE (score: 80)
#     → PL.GDY.VIA.NOK (score: 78)
#     → GDYNIAC (score: 75)
#   → GDYNIA.POLAND (score: 75)
#     → GDANSK/POLAND (score: 77)
#
# Group: GDYNIAVIANOK
# --------------------------------------------------
#   → GDYNIA.VIA (score: 82)
#     → GDYNIA.VIA.NOK (score: 100)
#     → GDYNIA (score: 100)
#     → GDYNIA.VIA.K.CANAL (score: 100)
#     → GDYNIA.VIA.KIEL (score: 100)
#     → GDYNIA.VIAE (score: 95)
#     → GDYNIA.VI (score: 95)
#     → GDYNIA.VIE (score: 90)
#     → GDYNIA.E (score: 86)
#     → GDYNIA.Y (score: 86)
#     → GDYNIA.TH (score: 80)
#     → GDYNIA.PL (score: 80)
#     → GDYNIA.VIBIA.NOK (score: 77)
#     → GDYNIA.VIK0/BPO (score: 75)
#     → GDYNIA.RSBURG (score: 75)
#     → GDYNIA.ROJECT (score: 75)
#     → GDYNIA.STELLE (score: 75)
#     → GDYNIA.RATION (score: 75)
#     → GDYNIA.DING.AREA (score: 75)
#     → GDYNIA/N.O.K (score: 75)
#     → GDYNIA.POLAND (score: 75)
#     → GDYNIA.VICINOUJSCIE (score: 75)
#   → GDYNIA.VIAE (score: 78)
#   → GDYNIA.VI (score: 76)
#     → GDYNIAC (score: 75)
#
# Group: HH.PS
# --------------------------------------------------
#   → HHLO.PS (score: 83)
#
# Group: KIEL.CANAL
# --------------------------------------------------
#   → KIEL.CANALTRANS (score: 80)
#
# Group: KLAIPEDA
# --------------------------------------------------
#   → KLAIPEDA.VIA.NOK (score: 100)
#     → NOK (score: 100)
#     → KLAIPEDA.VIA.NOC (score: 94)
#     → LT.KLAIPEDA (score: 84)
#     → KLJ.VIA.NOK (score: 78)
#     → KLAIPEDA.SWIN (score: 76)
#   → KLAIPEDA.SWIN (score: 100)
#   → KLAIPEDA.VIA.NOC (score: 100)
#   → LT.KLAIPEDA (score: 100)
#
# Group: PLGDY
# --------------------------------------------------
#   → PLGDY.NOK (score: 100)
#     → NOK (score: 100)
#     → PLGDY.VIA.NOK (score: 100)
#   → PLGDY.VIA.NOK (score: 100)
#     → PLGDN.VIA.NOK (score: 92)
#     → GDYNIA.VIA.NOK (score: 81)
#     → PL.GDY.VIA.NOK (score: 81)
#     → KLJ.VIA.NOK (score: 78)
#     → GDYNIA.VIBIA.NOK (score: 76)
#   → PLGDN (score: 80)

# %% [markdown]
# From this I will manually create a list of names that represent the same port, that do not have 100 match.
# As they can be incorrectly matched, and it would be better to do it manually.
#
# https://www.marinetraffic.com/en/ais/details/ports/347?name=HALMSTAD&country=Sweden

# %%
# df['start_fr_dest'].unique()

# %%
name_german = {
    'DEHAM': ["HAMBURG", "HAMBUG", "HH", "HAM"],
    'DEBRV': ["BREMERHAVEN", "BREMENHAVEN", "BRV", "DEBHV", "BHV"],
    'DEBRE': ["BREMEN", "BRE"],
    'DEKEL': ["KIEL", "KEL"],
    'DEHAM.FINKENWERDER': ["FINKENWERDER", "FINKENWERD"],
    'DEHAM.BLEXEN': ["BLEXEN"],
    'DESTA': ["STADE", "STAD", "STA"],
    'DEBRB' : ["BRUNSBUETTEL", "BRUNSBUETT", "BRB"],
    'DEHAM.ELBE': ["ELBE"],
    'DEVTT': ["HIDDENSEE", "VTT"],
    'DEWVN': ["WILHELMSHAVEN", "WVN"],
    'country': ["DE"]
}

name_poland = {
    'PLGDN': ["GDANSK", "GDANK", "GDN"],
    'PLGDY': ["GDYNIA", "GYDNIA", "GYDINIA", "GDY", "GDYNA"],
    'SZCZECIN': ["SZCZECIN", "SZCZECIN", "SZZ"],
     'country': ["PL"]
}

name_lythuania = {
    'LTKLJ': ["KLAIPEDA", "KLJ"],
    'country': ["LT"]
}

name_sweden = {
    'SEHAD': ["HALMSTAD", "HAD"],
    'SENOK': ["NOK"],
    'SEAHU': ["AHUS", "AHU"],
    'country': ["SE"]
}

name_russia = {
        'RUKGD': ["KALININGRAD", "KALININGRAD", "KAL"],
        'country': ["RU"]
}

name_denmark = {
    'DKKOB': ["KOBENHAVN", "COPENHAGEN", "COPENHAGUE", "CPH"],
    'country': ["DK"]
}

name_finland = {
    'FIHKO': ["HANKO", "HKO"],
    'country': ["FI"]
}

name_belgium = {
    "BEANR": ["BEANR", "ANR"],
    'country': ["BE"]
}
full_dict = [name_german, name_poland, name_lythuania, name_sweden, name_russia, name_finland, name_belgium]

def replace_with_key(df, column, name_variants):
    df[column] = df[column].apply(lambda x: match_names(x, name_variants))
    return df

# %%
df = replace_with_key(df, 'Destination', full_dict)
# df = replace_with_key(df, 'start_fr_dest', full_dict)
df[['Destination']].reset_index().drop_duplicates(subset=['Destination'])
# Out:
#            index    Destination
# 0              0          DEHAM
# 2894        2894          DEBRE
# 5160        5160          DEBRV
# 12382      12382  DEHAM.ELBE.RC
# 13229      13229  DEBRV.VIA.NOK
# ...          ...            ...
# 982201    982201          RUKGD
# 998470    998470       SZCZECIN
# 1004254  1004254          SEHAD
# 1039679  1039679   PLGDN.VIANOK
# 1056063  1056063        PLGDN.S
#
# [91 rows x 2 columns]

# %%
mask = df['Destination'].str.contains('.', na=False)
df.loc[mask, 'Destination'] = df.loc[mask, 'Destination'].str.split('.').str[0] # NOTE Remove everything after dot

# %%
# df[['start_fr_dest']].reset_index().drop_duplicates(subset=['start_fr_dest'])

# %% [markdown]
# 361854,387562,NORDEN.DEHAM
# Theoretically, I can switch places for it, but I am lazy
#
# Do we need to split it too? like debrv.via.nok?

# %%
save_path = '../../data/normalized_destinations.parquet'
df.to_parquet(save_path)
