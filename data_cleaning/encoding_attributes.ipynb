# %%
import os
import pandas as pd

# %%
file_path = '../data/fix_noise.parquet'
output_file_path = '../data/encoded.parquet'

if not os.path.exists(file_path):
    print(f"File not found: {file_path}")

df = pd.read_parquet(file_path)
# df.dtypes
